# %%
import pandas as pd
df = pd.read_csv("Advertising.csv")
df = df.iloc[:,1:len(df)]
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import seaborn as sns
sns.jointplot(x="TV", y="sales", data=df, kind="reg")

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[["TV"]] #bagimsiz degiskenimiz
X.head()
# Out:
#       TV
# 0  230.1
# 1   44.5
# 2   17.2
# 3  151.5
# 4  180.8

# %%
y = df[["sales"]] #bagimli degiskenimiz
y.head()
# Out:
#    sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
reg = LinearRegression()

# %%
model = reg.fit(X, y) #modeli kurmak anlamina gelir, fit demek.

# %%
model
# Out:
# LinearRegression()

# %%
str(model)
# Out:
# 'LinearRegression()'

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_n_features',
#  '_decision_function',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_preprocess_data',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_residues',
#  '_set_intercept',
#  '_validate_data',
#  'coef_',
#  'copy_X',
#  'fit',
#  'fit_intercept',
#  'get_params',
#  'intercept_',
#  'n_features_in_',
#  'n_jobs',
#  'normalize',
#  'positive',
#  'predict',
#  'rank_',
#  'score',
#  'set_params',
#  'singular_']

# %%
model.intercept_ #bu bizim b0 degerimiz.
# Out:
# array([7.03259355])

# %%
model.coef_ #bu da beta 1 katsayimiz.
# Out:
# array([[0.04753664]])

# %%
#rkare - bagimli degiskendeki degisikligin bagimsiz degiskenlerce aciklanma yuzdesidir.
model.score(X,y)
# Out:
# 0.611875050850071
